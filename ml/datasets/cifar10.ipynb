# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import tensorflow_datasets as tfds
from ml.datasets import get_dataset

# %matplotlib inline

data, info = get_dataset('cifar10', as_supervised=False)
data_train, data_test = data['train'], data['test']
print(data_train)
print(data_test)
fig = tfds.show_examples(info, data_test)
# Out:
# <_OptionsDataset shapes: {image: (32, 32, 3), label: ()}, types: {image: tf.uint8, label: tf.int64}>
# <_OptionsDataset shapes: {image: (32, 32, 3), label: ()}, types: {image: tf.uint8, label: tf.int64}>

# %% [markdown]
# |Number|Label Name|
# |:--:|:--:|
# |0|airplane|
# |1|automobile|
# |2|bird|
# |3|cat|
# |4|deer|
# |5|dog|
# |6|frog|
# |7|horse|
# |8|ship|
# |9|truck|

# %%
for example in data_train.take(1):  # Only take a single example
    image, label = example["image"], example["label"]
    
    plt.imshow(image)
    print(f"Label: {label.numpy()}")
# Out:
# Label: 9
